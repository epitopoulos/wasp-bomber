# %%
from math import dist
from copy import deepcopy
import pygad
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick

# — Optional: ensure any numpy-array printing uses max 3 decimals —
np.set_printoptions(precision=3, suppress=True)

# Data
nests = [
    {"id":1, "wasps":100, "x":25, "y":65},
    {"id":2, "wasps":200, "x":23, "y":8},
    {"id":3, "wasps":327, "x":7,  "y":13},
    {"id":4, "wasps":440, "x":95, "y":53},
    {"id":5, "wasps":450, "x":3,  "y":3},
    {"id":6, "wasps":639, "x":54, "y":56},
    {"id":7, "wasps":650, "x":67, "y":78},
    {"id":8, "wasps":678, "x":32, "y":4},
    {"id":9, "wasps":750, "x":24, "y":76},
    {"id":10,"wasps":801, "x":66, "y":89},
    {"id":11,"wasps":945, "x":84, "y":4},
    {"id":12,"wasps":967, "x":34, "y":23}
]

dmax = max(
    dist((a["x"], a["y"]), (b["x"], b["y"]))
    for a in nests for b in nests
)

def kill_function(n, d, dmax):
    return n * dmax / (20 * d + 1e-5)

def evaluate_solution(bombs, nests, dmax):
    nests_copy = deepcopy(nests)
    total_kills = 0

    for bomb in bombs:
        for nest in nests_copy:
            if nest["wasps"] == 0:
                continue
            d = dist((bomb["x"], bomb["y"]), (nest["x"], nest["y"]))
            kills = min(nest["wasps"], kill_function(nest["wasps"], d, dmax))
            total_kills += kills
            nest["wasps"] -= kills

    return total_kills

def fitness_func(ga_instance, solution, solution_idx):
    bombs = [
        {"x": solution[0], "y": solution[1]},
        {"x": solution[2], "y": solution[3]},
        {"x": solution[4], "y": solution[5]}
    ]
    score = evaluate_solution(bombs, nests, dmax)
    min_bomb_dist = min(
        dist((bombs[i]["x"], bombs[i]["y"]), (bombs[j]["x"], bombs[j]["y"]))
        for i in range(3) for j in range(i + 1, 3)
    )
    penalty = 100 * max(0, 10 - min_bomb_dist)
    return score - penalty

best_solutions = []
best_fitnesses = []

def local_search(solution, step=2):
    best_solution = solution.copy()
    best_score = fitness_func(None, best_solution, 0)
    for i in range(len(solution)):
        for delta in (-step, step):
            temp = solution.copy()
            temp[i] = np.clip(temp[i] + delta, 0, 100)
            score = fitness_func(None, temp, 0)
            if score > best_score:
                best_solution, best_score = temp.copy(), score
    return best_solution, best_score

def on_generation(ga):
    sol, fit, _ = ga.best_solution()
    improved_sol, improved_fit = local_search(sol)
    if improved_fit > fit:
        ga.population[0] = improved_sol
        sol, fit = improved_sol, improved_fit
    best_solutions.append(sol)
    best_fitnesses.append(fit)
    print(f"Generation {ga.generations_completed}: Best Fitness = {fit:.3f}")

# GA setup
gene_space = {"low": 0, "high": 100}
ga_instance = pygad.GA(
    num_generations=350,
    num_parents_mating=20,
    fitness_func=fitness_func,
    sol_per_pop=100,
    num_genes=6,
    gene_space=gene_space,
    parent_selection_type="sss",
    keep_parents=2,
    crossover_type="two_points",
    mutation_type="random",
    mutation_percent_genes=20,
    on_generation=on_generation
)

# Run
ga_instance.run()

# Results
solution, solution_fitness, _ = ga_instance.best_solution()
print("Best solution:", [round(x,3) for x in solution])
print(f"Wasp kills: {solution_fitness:.3f}")

# Helper for 3-decimal tick formatting
def format_axes(ax):
    fmt = mtick.FormatStrFormatter('%.3f')
    ax.xaxis.set_major_formatter(fmt)
    ax.yaxis.set_major_formatter(fmt)

# Plots
def plot_progress(fitnesses):
    plt.figure(figsize=(8,6))
    plt.plot(range(1, len(fitnesses)+1), fitnesses)
    plt.xlabel("Generation")
    plt.ylabel("Best Wasp Kills")
    plt.title("Progress of Best Solution per Generation")
    plt.grid(True)
    ax = plt.gca()
    format_axes(ax)
    plt.show()

def plot_solution(sol):
    bombs = [(sol[0], sol[1]), (sol[2], sol[3]), (sol[4], sol[5])]
    nest_coords = [(n['x'], n['y']) for n in nests]
    plt.figure(figsize=(8,8))
    plt.scatter(*zip(*nest_coords), color='orange', label='Nests', s=100)
    plt.scatter(*zip(*bombs), color='red', marker='X', label='Bombs', s=100)
    plt.xlim(0,100); plt.ylim(0,100); plt.grid(True); plt.legend()
    plt.title('Bomb and Nest Locations')
    ax = plt.gca()
    format_axes(ax)
    plt.show()

def plot_population(pop):
    nest_coords = [(n['x'], n['y']) for n in nests]
    plt.figure(figsize=(8,8))
    plt.scatter(*zip(*nest_coords), color='orange', label='Nests', s=100)
    for sol in pop:
        b = [(sol[0],sol[1]),(sol[2],sol[3]),(sol[4],sol[5])]
        plt.scatter(*zip(*b), color='blue', alpha=0.3, s=20)
    plt.xlim(0,100); plt.ylim(0,100); plt.grid(True); plt.legend(['Nests','Population Bombs'])
    plt.title('Population Bomb Positions in Last Generation')
    ax = plt.gca()
    format_axes(ax)
    plt.show()

# Show plots
plot_progress(best_fitnesses)
plot_solution(best_solutions[-1])
plot_population(ga_instance.population)
# Out:
# Generation 1: Best Fitness = 3696.634
# Generation 2: Best Fitness = 4022.468
# Generation 3: Best Fitness = 4167.586
# Generation 4: Best Fitness = 4196.650
# Generation 5: Best Fitness = 4407.005
# Generation 6: Best Fitness = 4411.318
# Generation 7: Best Fitness = 4411.318
# Generation 8: Best Fitness = 4419.919
# Generation 9: Best Fitness = 4446.402
# Generation 10: Best Fitness = 4446.402
# Generation 11: Best Fitness = 4457.664
# Generation 12: Best Fitness = 4457.664
# Generation 13: Best Fitness = 4461.886
# Generation 14: Best Fitness = 4461.886
# Generation 15: Best Fitness = 4460.967
# Generation 16: Best Fitness = 4460.967
# Generation 17: Best Fitness = 4460.967
# Generation 18: Best Fitness = 4460.967
# Generation 19: Best Fitness = 4460.967
# Generation 20: Best Fitness = 4460.967
# Generation 21: Best Fitness = 4460.967
# Generation 22: Best Fitness = 4460.967
# Generation 23: Best Fitness = 4460.967
# Generation 24: Best Fitness = 4460.967
# Generation 25: Best Fitness = 4460.967
# Generation 26: Best Fitness = 4460.967
# Generation 27: Best Fitness = 4460.967
# Generation 28: Best Fitness = 4460.967
# Generation 29: Best Fitness = 4460.967
# Generation 30: Best Fitness = 4460.967
# Generation 31: Best Fitness = 4488.166
# Generation 32: Best Fitness = 4495.988
# Generation 33: Best Fitness = 4495.988
# Generation 34: Best Fitness = 4495.988
# Generation 35: Best Fitness = 4495.988
# Generation 36: Best Fitness = 4495.988
# Generation 37: Best Fitness = 4495.988
# Generation 38: Best Fitness = 4495.988
# Generation 39: Best Fitness = 4495.988
# Generation 40: Best Fitness = 4495.988
# Generation 41: Best Fitness = 4495.988
# Generation 42: Best Fitness = 4495.988
# Generation 43: Best Fitness = 4495.988
# Generation 44: Best Fitness = 4495.988
# Generation 45: Best Fitness = 4495.988
# Generation 46: Best Fitness = 4495.988
# Generation 47: Best Fitness = 4495.988
# Generation 48: Best Fitness = 4495.988
# Generation 49: Best Fitness = 4495.988
# Generation 50: Best Fitness = 4505.094
# Generation 51: Best Fitness = 4505.094
# Generation 52: Best Fitness = 4501.665
# Generation 53: Best Fitness = 4501.665
# Generation 54: Best Fitness = 4508.224
# Generation 55: Best Fitness = 4508.224
# Generation 56: Best Fitness = 4508.224
# Generation 57: Best Fitness = 4508.224
# Generation 58: Best Fitness = 4508.224
# Generation 59: Best Fitness = 4508.224
# Generation 60: Best Fitness = 4508.224
# Generation 61: Best Fitness = 4508.224
# Generation 62: Best Fitness = 4508.224
# Generation 63: Best Fitness = 4508.224
# Generation 64: Best Fitness = 4508.224
# Generation 65: Best Fitness = 4508.224
# Generation 66: Best Fitness = 4508.224
# Generation 67: Best Fitness = 4508.224
# Generation 68: Best Fitness = 4508.224
# Generation 69: Best Fitness = 4508.224
# Generation 70: Best Fitness = 4508.224
# Generation 71: Best Fitness = 4508.224
# Generation 72: Best Fitness = 4508.224
# Generation 73: Best Fitness = 4508.224
# Generation 74: Best Fitness = 4510.712
# Generation 75: Best Fitness = 4515.231
# Generation 76: Best Fitness = 4515.231
# Generation 77: Best Fitness = 4515.231
# Generation 78: Best Fitness = 4513.159
# Generation 79: Best Fitness = 4513.159
# Generation 80: Best Fitness = 4513.159
# Generation 81: Best Fitness = 4513.159
# Generation 82: Best Fitness = 4513.159
# Generation 83: Best Fitness = 4513.159
# Generation 84: Best Fitness = 4513.159
# Generation 85: Best Fitness = 4513.159
# Generation 86: Best Fitness = 4513.159
# Generation 87: Best Fitness = 4513.159
# Generation 88: Best Fitness = 4513.159
# Generation 89: Best Fitness = 4513.159
# Generation 90: Best Fitness = 4513.159
# Generation 91: Best Fitness = 4513.159
# Generation 92: Best Fitness = 4513.159
# Generation 93: Best Fitness = 4513.159
# Generation 94: Best Fitness = 4513.159
# Generation 95: Best Fitness = 4513.159
# Generation 96: Best Fitness = 4513.159
# Generation 97: Best Fitness = 4513.159
# Generation 98: Best Fitness = 4513.159
# Generation 99: Best Fitness = 4513.159
# Generation 100: Best Fitness = 4513.159
# Generation 101: Best Fitness = 4513.159
# Generation 102: Best Fitness = 4513.159
# Generation 103: Best Fitness = 4513.159
# Generation 104: Best Fitness = 4513.159
# Generation 105: Best Fitness = 4513.159
# Generation 106: Best Fitness = 4513.159
# Generation 107: Best Fitness = 4513.159
# Generation 108: Best Fitness = 4513.159
# Generation 109: Best Fitness = 4513.159
# Generation 110: Best Fitness = 4513.159
# Generation 111: Best Fitness = 4513.159
# Generation 112: Best Fitness = 4513.159
# Generation 113: Best Fitness = 4513.159
# Generation 114: Best Fitness = 4513.159
# Generation 115: Best Fitness = 4513.159
# Generation 116: Best Fitness = 4513.159
# Generation 117: Best Fitness = 4513.159
# Generation 118: Best Fitness = 4513.159
# Generation 119: Best Fitness = 4513.159
# Generation 120: Best Fitness = 4513.159
# Generation 121: Best Fitness = 4513.159
# Generation 122: Best Fitness = 4513.159
# Generation 123: Best Fitness = 4513.159
# Generation 124: Best Fitness = 4513.159
# Generation 125: Best Fitness = 4513.159
# Generation 126: Best Fitness = 4513.159
# Generation 127: Best Fitness = 4513.159
# Generation 128: Best Fitness = 4513.159
# Generation 129: Best Fitness = 4513.159
# Generation 130: Best Fitness = 4513.159
# Generation 131: Best Fitness = 4513.159
# Generation 132: Best Fitness = 4513.159
# Generation 133: Best Fitness = 4513.159
# Generation 134: Best Fitness = 4513.159
# Generation 135: Best Fitness = 4513.159
# Generation 136: Best Fitness = 4513.159
# Generation 137: Best Fitness = 4513.159
# Generation 138: Best Fitness = 4513.159
# Generation 139: Best Fitness = 4513.159
# Generation 140: Best Fitness = 4513.159
# Generation 141: Best Fitness = 4513.159
# Generation 142: Best Fitness = 4513.159
# Generation 143: Best Fitness = 4513.159
# Generation 144: Best Fitness = 4513.159
# Generation 145: Best Fitness = 4513.159
# Generation 146: Best Fitness = 4513.159
# Generation 147: Best Fitness = 4513.159
# Generation 148: Best Fitness = 4513.159
# Generation 149: Best Fitness = 4513.159
# Generation 150: Best Fitness = 4513.159
# Generation 151: Best Fitness = 4513.159
# Generation 152: Best Fitness = 4513.159
# Generation 153: Best Fitness = 4513.159
# Generation 154: Best Fitness = 4513.159
# Generation 155: Best Fitness = 4513.159
# Generation 156: Best Fitness = 4513.159
# Generation 157: Best Fitness = 4513.159
# Generation 158: Best Fitness = 4513.159
# Generation 159: Best Fitness = 4513.159
# Generation 160: Best Fitness = 4513.159
# Generation 161: Best Fitness = 4513.159
# Generation 162: Best Fitness = 4513.159
# Generation 163: Best Fitness = 4513.159
# Generation 164: Best Fitness = 4513.159
# Generation 165: Best Fitness = 4513.159
# Generation 166: Best Fitness = 4513.159
# Generation 167: Best Fitness = 4513.159
# Generation 168: Best Fitness = 4513.159
# Generation 169: Best Fitness = 4513.159
# Generation 170: Best Fitness = 4513.159
# Generation 171: Best Fitness = 4513.159
# Generation 172: Best Fitness = 4513.159
# Generation 173: Best Fitness = 4513.159
# Generation 174: Best Fitness = 4513.159
# Generation 175: Best Fitness = 4513.159
# Generation 176: Best Fitness = 4514.053
# Generation 177: Best Fitness = 4514.053
# Generation 178: Best Fitness = 4514.053
# Generation 179: Best Fitness = 4514.053
# Generation 180: Best Fitness = 4514.053
# Generation 181: Best Fitness = 4514.053
# Generation 182: Best Fitness = 4514.053
# Generation 183: Best Fitness = 4514.053
# Generation 184: Best Fitness = 4514.053
# Generation 185: Best Fitness = 4514.053
# Generation 186: Best Fitness = 4514.231
# Generation 187: Best Fitness = 4514.231
# Generation 188: Best Fitness = 4514.231
# Generation 189: Best Fitness = 4514.231
# Generation 190: Best Fitness = 4514.231
# Generation 191: Best Fitness = 4514.231
# Generation 192: Best Fitness = 4514.231
# Generation 193: Best Fitness = 4514.231
# Generation 194: Best Fitness = 4514.231
# Generation 195: Best Fitness = 4514.231
# Generation 196: Best Fitness = 4514.231
# Generation 197: Best Fitness = 4514.231
# Generation 198: Best Fitness = 4514.231
# Generation 199: Best Fitness = 4514.231
# Generation 200: Best Fitness = 4514.231
# Generation 201: Best Fitness = 4514.231
# Generation 202: Best Fitness = 4514.231
# Generation 203: Best Fitness = 4514.231
# Generation 204: Best Fitness = 4514.231
# Generation 205: Best Fitness = 4514.231
# Generation 206: Best Fitness = 4514.231
# Generation 207: Best Fitness = 4514.231
# Generation 208: Best Fitness = 4514.231
# Generation 209: Best Fitness = 4514.231
# Generation 210: Best Fitness = 4514.231
# Generation 211: Best Fitness = 4514.231
# Generation 212: Best Fitness = 4514.231
# Generation 213: Best Fitness = 4514.231
# Generation 214: Best Fitness = 4514.231
# Generation 215: Best Fitness = 4514.231
# Generation 216: Best Fitness = 4514.231
# Generation 217: Best Fitness = 4514.231
# Generation 218: Best Fitness = 4514.231
# Generation 219: Best Fitness = 4514.231
# Generation 220: Best Fitness = 4514.231
# Generation 221: Best Fitness = 4514.231
# Generation 222: Best Fitness = 4514.231
# Generation 223: Best Fitness = 4514.231
# Generation 224: Best Fitness = 4514.231
# Generation 225: Best Fitness = 4514.231
# Generation 226: Best Fitness = 4514.231
# Generation 227: Best Fitness = 4514.231
# Generation 228: Best Fitness = 4514.231
# Generation 229: Best Fitness = 4514.231
# Generation 230: Best Fitness = 4514.231
# Generation 231: Best Fitness = 4514.231
# Generation 232: Best Fitness = 4514.231
# Generation 233: Best Fitness = 4514.231
# Generation 234: Best Fitness = 4514.355
# Generation 235: Best Fitness = 4514.355
# Generation 236: Best Fitness = 4514.355
# Generation 237: Best Fitness = 4514.355
# Generation 238: Best Fitness = 4514.355
# Generation 239: Best Fitness = 4514.355
# Generation 240: Best Fitness = 4514.355
# Generation 241: Best Fitness = 4514.355
# Generation 242: Best Fitness = 4514.355
# Generation 243: Best Fitness = 4514.355
# Generation 244: Best Fitness = 4514.355
# Generation 245: Best Fitness = 4514.355
# Generation 246: Best Fitness = 4514.355
# Generation 247: Best Fitness = 4514.355
# Generation 248: Best Fitness = 4514.355
# Generation 249: Best Fitness = 4514.355
# Generation 250: Best Fitness = 4514.355
# Generation 251: Best Fitness = 4514.355
# Generation 252: Best Fitness = 4514.355
# Generation 253: Best Fitness = 4514.355
# Generation 254: Best Fitness = 4514.355
# Generation 255: Best Fitness = 4514.355
# Generation 256: Best Fitness = 4514.355
# Generation 257: Best Fitness = 4516.354
# Generation 258: Best Fitness = 4516.354
# Generation 259: Best Fitness = 4516.354
# Generation 260: Best Fitness = 4516.354
# Generation 261: Best Fitness = 4516.354
# Generation 262: Best Fitness = 4516.354
# Generation 263: Best Fitness = 4516.354
# Generation 264: Best Fitness = 4516.354
# Generation 265: Best Fitness = 4516.354
# Generation 266: Best Fitness = 4516.354
# Generation 267: Best Fitness = 4516.354
# Generation 268: Best Fitness = 4516.354
# Generation 269: Best Fitness = 4516.354
# Generation 270: Best Fitness = 4516.354
# Generation 271: Best Fitness = 4516.354
# Generation 272: Best Fitness = 4516.354
# Generation 273: Best Fitness = 4516.354
# Generation 274: Best Fitness = 4516.354
# Generation 275: Best Fitness = 4516.354
# Generation 276: Best Fitness = 4516.354
# Generation 277: Best Fitness = 4516.354
# Generation 278: Best Fitness = 4519.704
# Generation 279: Best Fitness = 4519.704
# Generation 280: Best Fitness = 4519.704
# Generation 281: Best Fitness = 4519.704
# Generation 282: Best Fitness = 4519.704
# Generation 283: Best Fitness = 4519.704
# Generation 284: Best Fitness = 4519.704
# Generation 285: Best Fitness = 4519.704
# Generation 286: Best Fitness = 4519.704
# Generation 287: Best Fitness = 4519.704
# Generation 288: Best Fitness = 4519.704
# Generation 289: Best Fitness = 4519.704
# Generation 290: Best Fitness = 4519.704
# Generation 291: Best Fitness = 4519.704
# Generation 292: Best Fitness = 4519.704
# Generation 293: Best Fitness = 4519.704
# Generation 294: Best Fitness = 4519.704
# Generation 295: Best Fitness = 4519.704
# Generation 296: Best Fitness = 4519.704
# Generation 297: Best Fitness = 4519.704
# Generation 298: Best Fitness = 4519.704
# Generation 299: Best Fitness = 4519.704
# Generation 300: Best Fitness = 4519.704
# Generation 301: Best Fitness = 4519.704
# Generation 302: Best Fitness = 4519.704
# Generation 303: Best Fitness = 4519.704
# Generation 304: Best Fitness = 4519.704
# Generation 305: Best Fitness = 4519.704
# Generation 306: Best Fitness = 4519.704
# Generation 307: Best Fitness = 4519.704
# Generation 308: Best Fitness = 4519.704
# Generation 309: Best Fitness = 4519.704
# Generation 310: Best Fitness = 4519.704
# Generation 311: Best Fitness = 4519.704
# Generation 312: Best Fitness = 4519.704
# Generation 313: Best Fitness = 4519.704
# Generation 314: Best Fitness = 4519.704
# Generation 315: Best Fitness = 4519.704
# Generation 316: Best Fitness = 4519.704
# Generation 317: Best Fitness = 4519.704
# Generation 318: Best Fitness = 4519.704
# Generation 319: Best Fitness = 4519.704
# Generation 320: Best Fitness = 4519.704
# Generation 321: Best Fitness = 4519.704
# Generation 322: Best Fitness = 4519.704
# Generation 323: Best Fitness = 4519.704
# Generation 324: Best Fitness = 4519.704
# Generation 325: Best Fitness = 4519.704
# Generation 326: Best Fitness = 4519.704
# Generation 327: Best Fitness = 4519.704
# Generation 328: Best Fitness = 4519.704
# Generation 329: Best Fitness = 4519.704
# Generation 330: Best Fitness = 4519.704
# Generation 331: Best Fitness = 4519.704
# Generation 332: Best Fitness = 4519.704
# Generation 333: Best Fitness = 4519.704
# Generation 334: Best Fitness = 4519.704
# Generation 335: Best Fitness = 4519.704
# Generation 336: Best Fitness = 4519.704
# Generation 337: Best Fitness = 4519.704
# Generation 338: Best Fitness = 4519.704
# Generation 339: Best Fitness = 4519.704
# Generation 340: Best Fitness = 4519.704
# Generation 341: Best Fitness = 4519.704
# Generation 342: Best Fitness = 4519.704
# Generation 343: Best Fitness = 4519.704
# Generation 344: Best Fitness = 4519.704
# Generation 345: Best Fitness = 4519.704
# Generation 346: Best Fitness = 4519.704
# Generation 347: Best Fitness = 4519.704
# Generation 348: Best Fitness = 4519.704
# Generation 349: Best Fitness = 4519.704
# Generation 350: Best Fitness = 4519.704
# Best solution: [np.float64(66.234), np.float64(83.739), np.float64(80.285), np.float64(7.53), np.float64(31.381), np.float64(18.379)]
# Wasp kills: 4519.704
